# %%
import numpy as np
import pandas as pd

model = 'llama'
cutlayers = [1, 8, 15]
methods = ['ms', 'vq', 'qq', 'vs', 'fpq', 'rts']
baseline = np.load(f'baseline/{model}_perplexity.npy')

print(f'Baseline PPL {baseline[0]}-->{baseline[-1]}\n')

data = []
for method in methods:
    row = {'Method': method}
    for cutlayer in cutlayers:
        ppl = np.load(f'result/{model}_{cutlayer}_{method}_ppl.npy')[-1]
        ppl = np.inf if ppl == 1 else ppl
        row[f'Layer {cutlayer}'] = ppl - baseline[-1]
    data.append(row)

df = pd.DataFrame(data)

print(df.round(2))
# Out:
# Baseline PPL 68.63512201387714-->11.133335786562554
#
#   Method  Layer 1  Layer 8  Layer 15
# 0     ms     0.29     0.12      0.43
# 1     vq   591.39  1683.81   1016.62
# 2     qq   578.53      inf    864.08
# 3     vs  1594.80     6.87     12.27
# 4    fpq    67.36   665.23      3.43
# 5    rts  1717.51    18.93   3473.52

# %%
import numpy as np
import pandas as pd

model = 'qwen'
cutlayers = [1, 14, 27]
methods = ['ms', 'vq', 'qq', 'vs', 'fpq', 'rts']
baseline = np.load(f'baseline/{model}_perplexity.npy')

print(f'Baseline PPL {baseline[0]}-->{baseline[-1]}\n')

data = []
for method in methods:
    row = {'Method': method}
    for cutlayer in cutlayers:
        ppl = np.load(f'result/{model}_{cutlayer}_{method}_ppl.npy')[-1]
        ppl = np.inf if ppl == 1 else ppl
        row[f'Layer {cutlayer}'] = ppl - baseline[-1]
    data.append(row)

df = pd.DataFrame(data)

print(df.round(2))
# Out:
# Baseline PPL 52.54955357231076-->15.075763995806875
#
#   Method  Layer 1   Layer 14      Layer 27
# 0     ms     0.14       0.29  6.100000e-01
# 1     vq    13.72    1542.59  1.434120e+03
# 2     qq      inf  151921.10           inf
# 3     vs      inf       6.04  4.588176e+20
# 4    fpq     2.58        inf           inf
# 5    rts      inf      18.12  3.961500e+03

# %%
import numpy as np
import pandas as pd

model = 'llama'
cutlayers = [1, 8, 15]
methods = ['ms', 'vq', 'qq', 'vs', 'fpq', 'rts']
baseline = np.load(f'baseline/{model}_perplexity.npy')

print(f'Baseline PPL {baseline[0]}-->{baseline[-1]}\n')

data = []
for method in methods:
    row = {'Method': method}
    for cutlayer in cutlayers:
        ppl = np.load(f'result/{model}_{cutlayer}_{method}_ppl.npy')[0]
        row[f'Layer {cutlayer}'] = ppl - baseline[0]
    data.append(row)

df = pd.DataFrame(data)

print(df.round(2))
# Out:
# Baseline PPL 68.63512201387714-->11.133335786562554
#
#   Method     Layer 1     Layer 8    Layer 15
# 0     ms       10.63       -5.08        0.23
# 1     vq   218915.70  1925757.87  1881815.84
# 2     qq    34560.14   119130.43    53754.45
# 3     vs     4397.41      354.18      325.81
# 4    fpq  1788204.38    12992.36       71.10
# 5    rts    11524.22     1663.26      682.23

# %%
import numpy as np
import pandas as pd

model = 'qwen'
cutlayers = [1, 14, 27]
methods = ['ms', 'vq', 'qq', 'vs', 'fpq', 'rts']
baseline = np.load(f'baseline/{model}_perplexity.npy')

print(f'Baseline PPL {baseline[0]}-->{baseline[-1]}\n')

data = []
for method in methods:
    row = {'Method': method}
    for cutlayer in cutlayers:
        ppl = np.load(f'result/{model}_{cutlayer}_{method}_ppl.npy')[0]
        row[f'Layer {cutlayer}'] = ppl - baseline[0]
    data.append(row)

df = pd.DataFrame(data)

print(df.round(2))
# Out:
# Baseline PPL 52.54955357231076-->15.075763995806875
#
#   Method  Layer 1      Layer 14     Layer 27
# 0     ms     0.61  2.600000e-01         3.72
# 1     vq  9793.42  2.963190e+08  37515500.64
# 2     qq  1478.37  1.536123e+06     79821.40
# 3     vs  2527.65  1.065200e+02       202.55
# 4    fpq    93.83  1.675314e+04    229312.64
# 5    rts  6712.50  5.141800e+02       360.18

# %%
5.141800e+02
# Out:
# 514.18
